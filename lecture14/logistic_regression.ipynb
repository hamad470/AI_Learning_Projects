# %% [markdown]
# # Logistic Regression
# 1. cIs Binary Classification Algo
# 2. Use for Classification problem
# 3. Output will always in between 0-1
# 4. Linear Line Draw for classification
# 5. formula is f(xi) = 1/(1+e^-z)
# z = w0 + w1x1+w2x2+w3x3....wnxn
# 6. For cost function we use Cross-Entropy-loss
# ![image.png](attachment:image.png)

# %% [markdown]
# yi is the true label
# y^i is the predicted label that find by

# %% [markdown]
# # Gradient Decent
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
