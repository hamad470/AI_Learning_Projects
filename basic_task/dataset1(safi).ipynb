# %%
# !kaggle datasets download -d ganjerlawrence/mobile-phone-price-prediction-cleaned-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ganjerlawrence/mobile-phone-price-prediction-cleaned-dataset
# License(s): Apache 2.0
# ...
#   0%|          | 0.00/5.12k [00:00<?, ?B/s]
# 100%|██████████| 5.12k/5.12k [00:00<?, ?B/s]

# %%
import zipfile
with zipfile.ZipFile("mobile-phone-price-prediction-cleaned-dataset.zip",'r') as zip1:
    zip1.extractall(".")

# %%
import pandas as pd
import numpy as np
missing_values = ["n/a","na",np.nan]
dataframe1 = pd.read_csv("dataset 1(mobile).csv",na_values=missing_values)
dataframe1.isnull().sum()
# dataframe1.dropna
# Out:
# Ratings          0
# RAM              0
# ROM              0
# Mobile_Size      0
# Primary_Cam      0
# Selfi_Cam        0
# Battery_Power    0
# Price            0
# dtype: int64

# %%
import seaborn as sb
sb.heatmap(dataframe1.isnull(),xticklabels=False)
# Out:
# <Axes: >

# %%
numerical_data = dataframe1.select_dtypes(include=["number"]) 
numerical_data.head()
correlation = numerical_data.corr()
sb.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
dataframe1.dtypes
# Out:
# <bound method NDFrame.describe of      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0        4.3   4.0  128.0         6.00           48       13.0           4000
# 1        3.4   6.0   64.0         4.50           48       12.0           4000
# 2        4.3   4.0    4.0         4.50           64       16.0           4000
# 3        4.4   6.0   64.0         6.40           48       15.0           3800
# 4        4.5   6.0  128.0         6.18           35       15.0           3800
# ..       ...   ...    ...          ...          ...        ...            ...
# 802      3.8   6.0   32.0         4.54           48       12.0           2800
# 803      4.1   8.0   64.0         4.54           64        8.0           2500
# 804      4.4   3.0   32.0         6.20           48        1.0           3800
# 805      3.7  10.0   32.0         4.50           64        8.0           3500
# 806      3.5   6.0   32.0         4.50           64       15.0           1050
#
# ...

# %%
dataframe1.describe
# Out:
# <bound method NDFrame.describe of      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0        4.3   4.0  128.0         6.00           48       13.0           4000
# 1        3.4   6.0   64.0         4.50           48       12.0           4000
# 2        4.3   4.0    4.0         4.50           64       16.0           4000
# 3        4.4   6.0   64.0         6.40           48       15.0           3800
# 4        4.5   6.0  128.0         6.18           35       15.0           3800
# ..       ...   ...    ...          ...          ...        ...            ...
# 802      3.8   6.0   32.0         4.54           48       12.0           2800
# 803      4.1   8.0   64.0         4.54           64        8.0           2500
# 804      4.4   3.0   32.0         6.20           48        1.0           3800
# 805      3.7  10.0   32.0         4.50           64        8.0           3500
# 806      3.5   6.0   32.0         4.50           64       15.0           1050
#
# ...

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %%
df.replace("?",np.nan,inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 header= df[0]
#
# NameError: name 'df' is not defined
