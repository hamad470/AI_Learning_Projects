# %%
import pandas as pd

# %%
data ={
    'col1':[2,3,None,6,7,8,9],
    'col2':[1,2,3,4,5,6,7],
    'col3':[2,3,None,6,7,8,9],
    'col4':[1,2,3,4,5,6,7],
    'col5':[2,3,None,6,7,8,9],
    'col6':[1,2,3,4,5,6,7]
}

df = pd.DataFrame(data)
df
# Out:
#    col1  col2  col3  col4  col5  col6
# 0   2.0     1   2.0     1   2.0     1
# 1   3.0     2   3.0     2   3.0     2
# 2   NaN     3   NaN     3   NaN     3
# 3   6.0     4   6.0     4   6.0     4
# 4   7.0     5   7.0     5   7.0     5
# 5   8.0     6   8.0     6   8.0     6
# 6   9.0     7   9.0     7   9.0     7

# %%
df.to_csv("practice.csv")
df.to_excel("practice.xlsx")

# %%
df = pd.read_csv("practice.csv")
df
# Out:
#    Unnamed: 0  col1  col2  col3  col4  col5  col6
# 0           0   2.0     1   2.0     1   2.0     1
# 1           1   3.0     2   3.0     2   3.0     2
# 2           2   NaN     3   NaN     3   NaN     3
# 3           3   6.0     4   6.0     4   6.0     4
# 4           4   7.0     5   7.0     5   7.0     5
# 5           5   8.0     6   8.0     6   8.0     6
# 6           6   9.0     7   9.0     7   9.0     7

# %%
df[["col1","col2","col3","col4","col5","col6"]]
# Out:
#    col1  col2  col3  col4  col5  col6
# 0   2.0     1   2.0     1   2.0     1
# 1   3.0     2   3.0     2   3.0     2
# 2   NaN     3   NaN     3   NaN     3
# 3   6.0     4   6.0     4   6.0     4
# 4   7.0     5   7.0     5   7.0     5
# 5   8.0     6   8.0     6   8.0     6
# 6   9.0     7   9.0     7   9.0     7

# %%
df["col7"] = df["col1"]+df["col2"]
df
# Out:
#    Unnamed: 0  col1  col2  col3  col4  col5  col6  col7
# 0           0   2.0     1   2.0     1   2.0     1   3.0
# 1           1   3.0     2   3.0     2   3.0     2   5.0
# 2           2   NaN     3   NaN     3   NaN     3   NaN
# 3           3   6.0     4   6.0     4   6.0     4  10.0
# 4           4   7.0     5   7.0     5   7.0     5  12.0
# 5           5   8.0     6   8.0     6   8.0     6  14.0
# 6           6   9.0     7   9.0     7   9.0     7  16.0

# %%
print(df.head())
print(df.tail())
# Out:
#    Unnamed: 0  col1  col2  col3  col4  col5  col6  col7
# 0           0   2.0     1   2.0     1   2.0     1   3.0
# 1           1   3.0     2   3.0     2   3.0     2   5.0
# 2           2   NaN     3   NaN     3   NaN     3   NaN
# 3           3   6.0     4   6.0     4   6.0     4  10.0
# 4           4   7.0     5   7.0     5   7.0     5  12.0
#    Unnamed: 0  col1  col2  col3  col4  col5  col6  col7
# 2           2   NaN     3   NaN     3   NaN     3   NaN
# 3           3   6.0     4   6.0     4   6.0     4  10.0
# 4           4   7.0     5   7.0     5   7.0     5  12.0
# 5           5   8.0     6   8.0     6   8.0     6  14.0
# 6           6   9.0     7   9.0     7   9.0     7  16.0

# %%
print(df.describe())
print("DATA INFORMATION")
print(df.info())
# Out:
#        Unnamed: 0      col1      col2      col3      col4      col5      col6  \
# count    7.000000  6.000000  7.000000  6.000000  7.000000  6.000000  7.000000
# mean     3.000000  5.833333  4.000000  5.833333  4.000000  5.833333  4.000000
# std      2.160247  2.786874  2.160247  2.786874  2.160247  2.786874  2.160247
# min      0.000000  2.000000  1.000000  2.000000  1.000000  2.000000  1.000000
# 25%      1.500000  3.750000  2.500000  3.750000  2.500000  3.750000  2.500000
# 50%      3.000000  6.500000  4.000000  6.500000  4.000000  6.500000  4.000000
# 75%      4.500000  7.750000  5.500000  7.750000  5.500000  7.750000  5.500000
# max      6.000000  9.000000  7.000000  9.000000  7.000000  9.000000  7.000000
#
#            col7
# count   6.00000
# mean   10.00000
# std     5.09902
# min     3.00000
# 25%     6.25000
# 50%    11.00000
# 75%    13.50000
# max    16.00000
# DATA INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  7 non-null      int64
#  1   col1        6 non-null      float64
#  2   col2        7 non-null      int64
#  3   col3        6 non-null      float64
#  4   col4        7 non-null      int64
#  5   col5        6 non-null      float64
#  6   col6        7 non-null      int64
#  7   col7        6 non-null      float64
# dtypes: float64(4), int64(4)
# memory usage: 576.0 bytes
# None

# %%
df.plot()
# Out:
# <Axes: >

# %%
print(df['col1'])
print(df['col2'].values)
# Out:
# 0    2.0
# 1    3.0
# 2    NaN
# 3    6.0
# 4    7.0
# 5    8.0
# 6    9.0
# Name: col1, dtype: float64
# [1 2 3 4 5 6 7]

# %%
from statistics import mean
import math

# %%
# s = sum(int(df['col2']))
# l = len(df['col2'])
# avg = s/l
# # ave = mean(df['col1'])
# print(ave)
# df.fillna(ave,inplace=True)
# df

# %%
df.dropna()
# Out:
#    Unnamed: 0  col1  col2  col3  col4  col5  col6  col7
# 0           0   2.0     1   2.0     1   2.0     1   3.0
# 1           1   3.0     2   3.0     2   3.0     2   5.0
# 3           3   6.0     4   6.0     4   6.0     4  10.0
# 4           4   7.0     5   7.0     5   7.0     5  12.0
# 5           5   8.0     6   8.0     6   8.0     6  14.0
# 6           6   9.0     7   9.0     7   9.0     7  16.0

# %%
df.drop_duplicates()
# Out:
#    Unnamed: 0  col1  col2  col3  col4  col5  col6  col7
# 0           0   2.0     1   2.0     1   2.0     1   3.0
# 1           1   3.0     2   3.0     2   3.0     2   5.0
# 2           2   NaN     3   NaN     3   NaN     3   NaN
# 3           3   6.0     4   6.0     4   6.0     4  10.0
# 4           4   7.0     5   7.0     5   7.0     5  12.0
# 5           5   8.0     6   8.0     6   8.0     6  14.0
# 6           6   9.0     7   9.0     7   9.0     7  16.0

# %%
df.columns
numerical_columns = df.select_dtypes(include=['number']).columns
print(numerical_columns)
categorical = df.select_dtypes(include=['object','bool']).columns
print(categorical)
# Out:
# Index(['Unnamed: 0', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7'], dtype='object')
# Index([], dtype='object')

# %%
df2 = pd.read_csv('/home/rahmat/Desktop/Data csv file for ML/Housing.csv')
df2
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
numerical_data = df2.select_dtypes(include=['number'])
categorical_data = df2.select_dtypes(include=['object','bool'])

# print("categorical")
# print(categorical_data)

print("numerical_columns")
print(numerical_data.head())
print("categorical_data")
print(categorical_data.head())
# Out:
# numerical_columns
#       price  area  bedrooms  bathrooms  stories  parking
# 0  13300000  7420         4          2        3        2
# 1  12250000  8960         4          4        4        3
# 2  12250000  9960         3          2        2        2
# 3  12215000  7500         4          2        2        3
# 4  11410000  7420         4          1        2        2
# categorical_data
#   mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0      yes        no       no              no             yes      yes
# 1      yes        no       no              no             yes       no
# 2      yes        no      yes              no              no      yes
# 3      yes        no      yes              no             yes      yes
# 4      yes       yes      yes              no             yes       no
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter('price','area','stories',data=numerical_data)

# %%
plt.plot(numerical_data['price'],numerical_data['area'])

# %%
import seaborn as sb

# %%
corelation = numerical_data.corr()
plt.figure(figsize=(8,6))
sb.heatmap(corelation,annot=True,cmap="coolwarm")
plt.show()
