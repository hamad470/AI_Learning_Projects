# %%
import numpy as np
data = np.zeros( (512,512,3), dtype=np.uint8)
data[256,256] = [222,222,222]

# %%
data = np.zeros( (512,512,22), dtype=np.uint8)
data[256,256] = [255,1,0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 data = np.zeros( (512,512,22), dtype=np.uint8)
# ----> 2 data[256,256] = [255,1,0]
#
# ValueError: could not broadcast input array from shape (3,) into shape (22,)

# %%
from matplotlib import pyplot as plt
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Create a 512x512 image with black background
data = np.zeros((512, 512, 3), dtype=np.uint8)

# Set a 50x50 block of pixels to white (or any other color)
data[200:276, 236:276] = [222, 222, 222]

# Display the image
plt.imshow(data, interpolation='nearest')
plt.show()
